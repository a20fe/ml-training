# %%
import numpy as np
import pandas as pd 
credits=pd.read_csv('credits.csv')
movies =pd.read_csv('movies.csv')

# %%
movies=movies.merge(credits , on="title")

# %%
movies.shape
# Out:
# (4808, 23)

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4803     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4804       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4805          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4806          0                                                 []
# 4807          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4803                                                NaN    9367
# 4804                                                NaN   72766
# 4805  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4806                        http://shanghaicalling.com/  126186
# 4807                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4803  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4804                                                 []                en
# 4805  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4806                                                 []                en
# 4807  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4803                               El Mariachi
# 4804                                 Newlyweds
# 4805                 Signed, Sealed, Delivered
# 4806                          Shanghai Calling
# 4807                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4803  El Mariachi just wants to play his guitar and ...   14.269792
# 4804  A newlywed couple's honeymoon is upended by th...    0.642552
# 4805  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4806  When ambitious New York attorney Sam is sent t...    0.857008
# 4807  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  ... runtime  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
# ...                                                 ...  ...     ...
# 4803           [{"name": "Columbia Pictures", "id": 5}]  ...    81.0
# 4804                                                 []  ...    85.0
# 4805  [{"name": "Front Street Pictures", "id": 3958}...  ...   120.0
# 4806                                                 []  ...    98.0
# 4807  [{"name": "rusty bear entertainment", "id": 87...  ...    90.0
#
#                                        spoken_languages    status  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1              [{"iso_639_1": "en", "name": "English"}]  Released
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3              [{"iso_639_1": "en", "name": "English"}]  Released
# 4              [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                 ...       ...
# 4803      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 4804                                                 []  Released
# 4805           [{"iso_639_1": "en", "name": "English"}]  Released
# 4806           [{"iso_639_1": "en", "name": "English"}]  Released
# 4807           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4803  He didn't come looking for trouble, but troubl...
# 4804  A newlywed couple's honeymoon is upended by th...
# 4805                                                NaN
# 4806                           A New Yorker in Shanghai
# 4807                                                NaN
#
#                                          title vote_average vote_count  \
# 0                                       Avatar          7.2      11800
# 1     Pirates of the Caribbean: At World's End          6.9       4500
# 2                                      Spectre          6.3       4466
# 3                        The Dark Knight Rises          7.6       9106
# 4                                  John Carter          6.1       2124
# ...                                        ...          ...        ...
# 4803                               El Mariachi          6.6        238
# 4804                                 Newlyweds          5.9          5
# 4805                 Signed, Sealed, Delivered          7.0          6
# 4806                          Shanghai Calling          5.7          7
# 4807                         My Date with Drew          6.3         16
#
#      movie_id                                               cast  \
# 0       19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1         285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2      206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3       49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...       ...                                                ...
# 4803     9367  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4804    72766  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4805   231617  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4806   126186  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4807    25975  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4803  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4804  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4805  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4806  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4807  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4808 rows x 23 columns]

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'cast', 'crew'],
#       dtype='object')

# %%
movies=movies[['keywords' ,'title','movie_id','cast', 'crew','overview', 'genres','popularity']]

# %%
movies
# Out:
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4     [{"id": 818, "name": "based on novel"}, {"id":...
# ...                                                 ...
# 4803  [{"id": 5616, "name": "united states\u2013mexi...
# 4804                                                 []
# 4805  [{"id": 248, "name": "date"}, {"id": 699, "nam...
# 4806                                                 []
# 4807  [{"id": 1523, "name": "obsession"}, {"id": 224...
#
#                                          title  movie_id  \
# 0                                       Avatar     19995
# 1     Pirates of the Caribbean: At World's End       285
# 2                                      Spectre    206647
# 3                        The Dark Knight Rises     49026
# 4                                  John Carter     49529
# ...                                        ...       ...
# 4803                               El Mariachi      9367
# 4804                                 Newlyweds     72766
# 4805                 Signed, Sealed, Delivered    231617
# 4806                          Shanghai Calling    126186
# 4807                         My Date with Drew     25975
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4803  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4804  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4805  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4806  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4807  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew  \
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4803  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4804  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4805  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4806  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4807  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4803  El Mariachi just wants to play his guitar and ...
# 4804  A newlywed couple's honeymoon is upended by th...
# 4805  "Signed, Sealed, Delivered" introduces a dedic...
# 4806  When ambitious New York attorney Sam is sent t...
# 4807  Ever since the second grade when he first saw ...
#
#                                                  genres  popularity
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  150.437577
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...  139.082615
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  107.376788
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...  112.312950
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   43.926995
# ...                                                 ...         ...
# 4803  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   14.269792
# 4804  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...    0.642552
# 4805  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...    1.444476
# 4806                                                 []    0.857008
# 4807                [{"id": 99, "name": "Documentary"}]    1.929883
#
# [4808 rows x 8 columns]

# %%
movies.isnull().sum()
# Out:
# keywords      0
# title         0
# movie_id      0
# cast          0
# crew          0
# overview      3
# genres        0
# popularity    0
# dtype: int64

# %%
movies.dropna(inplace=True)
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\3786870272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
import ast
def convert(obj):
    try:
        cast_list = ast.literal_eval(obj)
        return [actor['name'] for actor in cast_list[:]]
    except (ValueError, SyntaxError):
        return []

# %%
movies['genres']=movies['genres'].apply(convert)
movies['keywords']=movies['keywords'].apply(convert)
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\4201180745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres']=movies['genres'].apply(convert)
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\4201180745.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords']=movies['keywords'].apply(convert)

# %%
def convert3(obj):
    try:
        cast_list = ast.literal_eval(obj)
        return [actor['name'] for actor in cast_list[:3]]
    except (ValueError, SyntaxError):
        return []
    return l

# %%
movies['cast']=movies['cast'].apply(convert3)
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\670030197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast']=movies['cast'].apply(convert3)

# %%
movies
# Out:
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# 3     [dc comics, crime fighter, terrorist, secret i...
# 4     [based on novel, mars, medallion, space travel...
# ...                                                 ...
# 4803  [united states–mexico barrier, legs, arms, pap...
# 4804                                                 []
# 4805  [date, love at first sight, narration, investi...
# 4806                                                 []
# 4807          [obsession, camcorder, crush, dream girl]
#
#                                          title  movie_id  \
# 0                                       Avatar     19995
# 1     Pirates of the Caribbean: At World's End       285
# 2                                      Spectre    206647
# 3                        The Dark Knight Rises     49026
# 4                                  John Carter     49529
# ...                                        ...       ...
# 4803                               El Mariachi      9367
# 4804                                 Newlyweds     72766
# 4805                 Signed, Sealed, Delivered    231617
# 4806                          Shanghai Calling    126186
# 4807                         My Date with Drew     25975
#
#                                                    cast  \
# 0      [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1         [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2          [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3          [Christian Bale, Michael Caine, Gary Oldman]
# 4        [Taylor Kitsch, Lynn Collins, Samantha Morton]
# ...                                                 ...
# 4803  [Carlos Gallardo, Jaime de Hoyos, Peter Marqua...
# 4804       [Edward Burns, Kerry Bishé, Marsha Dietlein]
# 4805         [Eric Mabius, Kristin Booth, Crystal Lowe]
# 4806          [Daniel Henney, Eliza Coupe, Bill Paxton]
# 4807  [Drew Barrymore, Brian Herzlinger, Corey Feldman]
#
#                                                    crew  \
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4803  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4804  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4805  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4806  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4807  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4803  El Mariachi just wants to play his guitar and ...
# 4804  A newlywed couple's honeymoon is upended by th...
# 4805  "Signed, Sealed, Delivered" introduces a dedic...
# 4806  When ambitious New York attorney Sam is sent t...
# 4807  Ever since the second grade when he first saw ...
#
#                                              genres  popularity
# 0     [Action, Adventure, Fantasy, Science Fiction]  150.437577
# 1                      [Adventure, Fantasy, Action]  139.082615
# 2                        [Action, Adventure, Crime]  107.376788
# 3                  [Action, Crime, Drama, Thriller]  112.312950
# 4              [Action, Adventure, Science Fiction]   43.926995
# ...                                             ...         ...
# 4803                      [Action, Crime, Thriller]   14.269792
# 4804                              [Comedy, Romance]    0.642552
# 4805             [Comedy, Drama, Romance, TV Movie]    1.444476
# 4806                                             []    0.857008
# 4807                                  [Documentary]    1.929883
#
# [4805 rows x 8 columns]

# %%
def fetsh_director(obj):
    try: 
        l = []
        for i in ast.literal_eval(obj):
            if i['job'] == 'Director':
                l.append(i['name'])
    except (ValueError, SyntaxError):
        return l
    return l

# %%
movies['crew']=movies['crew'].apply(fetsh_director)
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\245155144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew']=movies['crew'].apply(fetsh_director)

# %%
movies
# Out:
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# 3     [dc comics, crime fighter, terrorist, secret i...
# 4     [based on novel, mars, medallion, space travel...
# ...                                                 ...
# 4803  [united states–mexico barrier, legs, arms, pap...
# 4804                                                 []
# 4805  [date, love at first sight, narration, investi...
# 4806                                                 []
# 4807          [obsession, camcorder, crush, dream girl]
#
#                                          title  movie_id  \
# 0                                       Avatar     19995
# 1     Pirates of the Caribbean: At World's End       285
# 2                                      Spectre    206647
# 3                        The Dark Knight Rises     49026
# 4                                  John Carter     49529
# ...                                        ...       ...
# 4803                               El Mariachi      9367
# 4804                                 Newlyweds     72766
# 4805                 Signed, Sealed, Delivered    231617
# 4806                          Shanghai Calling    126186
# 4807                         My Date with Drew     25975
#
#                                                    cast  \
# 0      [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1         [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2          [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3          [Christian Bale, Michael Caine, Gary Oldman]
# 4        [Taylor Kitsch, Lynn Collins, Samantha Morton]
# ...                                                 ...
# 4803  [Carlos Gallardo, Jaime de Hoyos, Peter Marqua...
# 4804       [Edward Burns, Kerry Bishé, Marsha Dietlein]
# 4805         [Eric Mabius, Kristin Booth, Crystal Lowe]
# 4806          [Daniel Henney, Eliza Coupe, Bill Paxton]
# 4807  [Drew Barrymore, Brian Herzlinger, Corey Feldman]
#
#                                           crew  \
# 0                              [James Cameron]
# 1                             [Gore Verbinski]
# 2                                 [Sam Mendes]
# 3                          [Christopher Nolan]
# 4                             [Andrew Stanton]
# ...                                        ...
# 4803                        [Robert Rodriguez]
# 4804                            [Edward Burns]
# 4805                             [Scott Smith]
# 4806                             [Daniel Hsia]
# 4807  [Brian Herzlinger, Jon Gunn, Brett Winn]
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4803  El Mariachi just wants to play his guitar and ...
# 4804  A newlywed couple's honeymoon is upended by th...
# 4805  "Signed, Sealed, Delivered" introduces a dedic...
# 4806  When ambitious New York attorney Sam is sent t...
# 4807  Ever since the second grade when he first saw ...
#
#                                              genres  popularity
# 0     [Action, Adventure, Fantasy, Science Fiction]  150.437577
# 1                      [Adventure, Fantasy, Action]  139.082615
# 2                        [Action, Adventure, Crime]  107.376788
# 3                  [Action, Crime, Drama, Thriller]  112.312950
# 4              [Action, Adventure, Science Fiction]   43.926995
# ...                                             ...         ...
# 4803                      [Action, Crime, Thriller]   14.269792
# 4804                              [Comedy, Romance]    0.642552
# 4805             [Comedy, Drama, Romance, TV Movie]    1.444476
# 4806                                             []    0.857008
# 4807                                  [Documentary]    1.929883
#
# [4805 rows x 8 columns]

# %%
movies['overview'] = movies['overview'].apply(lambda x :x.split())
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\3777584746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['overview'] = movies['overview'].apply(lambda x :x.split())

# %%
movies['overview'][0]
# Out:
# ['In',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.']

# %%
movies['genres']=movies['genres'].apply(lambda x :[i.replace(" ","") for i in x])
movies['keywords']=movies['keywords'].apply(lambda x :[i.replace(" ","") for i in x])
movies['cast']=movies['cast'].apply(lambda x :[i.replace(" ","") for i in x])
movies['crew']=movies['crew'].apply(lambda x :[i.replace(" ","") for i in x])
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\1856182986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres']=movies['genres'].apply(lambda x :[i.replace(" ","") for i in x])
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\1856182986.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords']=movies['keywords'].apply(lambda x :[i.replace(" ","") for i in x])
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\1856182986.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast']=movies['cast'].apply(lambda x :[i.replace(" ","") for i in x])
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\1856182986.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew']=movies['crew'].apply(lambda x :[i.replace(" ","") for i in x])

# %%
movies
# Out:
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3     [dccomics, crimefighter, terrorist, secretiden...
# 4     [basedonnovel, mars, medallion, spacetravel, p...
# ...                                                 ...
# 4803  [unitedstates–mexicobarrier, legs, arms, paper...
# 4804                                                 []
# 4805  [date, loveatfirstsight, narration, investigat...
# 4806                                                 []
# 4807           [obsession, camcorder, crush, dreamgirl]
#
#                                          title  movie_id  \
# 0                                       Avatar     19995
# 1     Pirates of the Caribbean: At World's End       285
# 2                                      Spectre    206647
# 3                        The Dark Knight Rises     49026
# 4                                  John Carter     49529
# ...                                        ...       ...
# 4803                               El Mariachi      9367
# 4804                                 Newlyweds     72766
# 4805                 Signed, Sealed, Delivered    231617
# 4806                          Shanghai Calling    126186
# 4807                         My Date with Drew     25975
#
#                                                 cast  \
# 0      [SamWorthington, ZoeSaldana, SigourneyWeaver]
# 1         [JohnnyDepp, OrlandoBloom, KeiraKnightley]
# 2          [DanielCraig, ChristophWaltz, LéaSeydoux]
# 3          [ChristianBale, MichaelCaine, GaryOldman]
# 4        [TaylorKitsch, LynnCollins, SamanthaMorton]
# ...                                              ...
# 4803  [CarlosGallardo, JaimedeHoyos, PeterMarquardt]
# 4804       [EdwardBurns, KerryBishé, MarshaDietlein]
# 4805         [EricMabius, KristinBooth, CrystalLowe]
# 4806          [DanielHenney, ElizaCoupe, BillPaxton]
# 4807  [DrewBarrymore, BrianHerzlinger, CoreyFeldman]
#
#                                        crew  \
# 0                            [JamesCameron]
# 1                           [GoreVerbinski]
# 2                               [SamMendes]
# 3                        [ChristopherNolan]
# 4                           [AndrewStanton]
# ...                                     ...
# 4803                      [RobertRodriguez]
# 4804                          [EdwardBurns]
# 4805                           [ScottSmith]
# 4806                           [DanielHsia]
# 4807  [BrianHerzlinger, JonGunn, BrettWinn]
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# 4     [John, Carter, is, a, war-weary,, former, mili...
# ...                                                 ...
# 4803  [El, Mariachi, just, wants, to, play, his, gui...
# 4804  [A, newlywed, couple's, honeymoon, is, upended...
# 4805  ["Signed,, Sealed,, Delivered", introduces, a,...
# 4806  [When, ambitious, New, York, attorney, Sam, is...
# 4807  [Ever, since, the, second, grade, when, he, fi...
#
#                                             genres  popularity
# 0     [Action, Adventure, Fantasy, ScienceFiction]  150.437577
# 1                     [Adventure, Fantasy, Action]  139.082615
# 2                       [Action, Adventure, Crime]  107.376788
# 3                 [Action, Crime, Drama, Thriller]  112.312950
# 4              [Action, Adventure, ScienceFiction]   43.926995
# ...                                            ...         ...
# 4803                     [Action, Crime, Thriller]   14.269792
# 4804                             [Comedy, Romance]    0.642552
# 4805             [Comedy, Drama, Romance, TVMovie]    1.444476
# 4806                                            []    0.857008
# 4807                                 [Documentary]    1.929883
#
# [4805 rows x 8 columns]

# %%
movies['tags']=movies['overview']+movies['genres']+movies['cast']+movies['crew']+movies['keywords']
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\3831186968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags']=movies['overview']+movies['genres']+movies['cast']+movies['crew']+movies['keywords']

# %%
new_df = movies[['movie_id' , 'title' ,'tags']]

# %%
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                    tags
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# 4     [John, Carter, is, a, war-weary,, former, mili...
# ...                                                 ...
# 4803  [El, Mariachi, just, wants, to, play, his, gui...
# 4804  [A, newlywed, couple's, honeymoon, is, upended...
# 4805  ["Signed,, Sealed,, Delivered", introduces, a,...
# 4806  [When, ambitious, New, York, attorney, Sam, is...
# 4807  [Ever, since, the, second, grade, when, he, fi...
#
# [4805 rows x 3 columns]

# %%
new_df['tags']=new_df['tags'].apply(lambda x: " ".join (x))
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\746906390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x: " ".join (x))

# %%
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                    tags
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4803  El Mariachi just wants to play his guitar and ...
# 4804  A newlywed couple's honeymoon is upended by th...
# 4805  "Signed, Sealed, Delivered" introduces a dedic...
# 4806  When ambitious New York attorney Sam is sent t...
# 4807  Ever since the second grade when he first saw ...
#
# [4805 rows x 3 columns]

# %%
new_df['tags']=new_df['tags'].apply(lambda x :x.lower())
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\991987069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x :x.lower())

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=5000 , stop_words='english')

# %%
cv.fit_transform(new_df['tags']).toarray().shape
# Out:
# (4805, 5000)

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
len(cv.get_feature_names_out())
# Out:
# 5000

# %%
vectors.shape
# Out:
# (4805, 5000)

# %%
import nltk 
from nltk.stem.porter import PorterStemmer

# %%
ps =PorterStemmer()

# %%
def stem(text):
    y = [] 
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# C:\Users\ELSAWAH\AppData\Local\Temp\ipykernel_10784\3816344688.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity =cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.08964215, 0.05976143, ..., 0.02548236, 0.02672612,
#        0.        ])

# %%
sorted(list(enumerate(similarity[0])),reverse=True , key =lambda x:x[1])[1:6]
# Out:
# [(539, 0.26089696604360174),
#  (507, 0.25302403842552984),
#  (1194, 0.25226248955475644),
#  (1216, 0.2480694691784169),
#  (582, 0.24397501823713333)]

# %%
def recommend(movie):
    movie_index=new_df[new_df['title']==movie].index[0]
    distance=similarity[movie_index]
    movies_list=sorted(list(enumerate(distance)),reverse=True , key=lambda x:x[1])[1:6]
    for i in movies_list :
        print(new_df.iloc[i[0]].title)

# %%
recommend('Avatar')
# Out:
# Titan A.E.
# Independence Day
# Small Soldiers
# Aliens vs Predator: Requiem
# Battle: Los Angeles

# %%
recommend('Iron Man')
# Out:
# Iron Man 2
# Iron Man 3
# Avengers: Age of Ultron
# Captain America: Civil War
# The Avengers
